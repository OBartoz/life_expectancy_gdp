# %% [markdown]
# # Introduction

# %% [markdown]
# Download required packages for analysis:

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# Download data to analyse:

# %%
df_raw = pd.read_csv("all_data.csv")

# %% [markdown]
# ## Explore & Clean Data

# %%
print(df_raw.head(20))
# Out:
#    Country  Year  Life expectancy at birth (years)           GDP
# 0    Chile  2000                              77.3  7.786093e+10
# 1    Chile  2001                              77.3  7.097992e+10
# 2    Chile  2002                              77.8  6.973681e+10
# 3    Chile  2003                              77.9  7.564346e+10
# 4    Chile  2004                              78.0  9.921039e+10
# 5    Chile  2005                              78.4  1.229650e+11
# 6    Chile  2006                              78.9  1.547880e+11
# 7    Chile  2007                              78.9  1.736060e+11
# 8    Chile  2008                              79.6  1.796380e+11
# 9    Chile  2009                              79.3  1.723890e+11
# 10   Chile  2010                              79.1  2.185380e+11
# 11   Chile  2011                              79.8  2.522520e+11
# 12   Chile  2012                              79.9  2.671220e+11
# ...

# %%
print(df_raw.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96 entries, 0 to 95
# Data columns (total 4 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Country                           96 non-null     object
#  1   Year                              96 non-null     int64
#  2   Life expectancy at birth (years)  96 non-null     float64
#  3   GDP                               96 non-null     float64
# dtypes: float64(2), int64(1), object(1)
# memory usage: 3.1+ KB
# None

# %% [markdown]
# Based on the first rows in the df, there could only be duplicates across the Country and Year columns combined. So here, they are preemptively removed.

# %%
df_new = df_raw.drop_duplicates(
  subset = ['Country', 'Year'],
  keep = 'last').reset_index(drop = True)

# %%
print(df_new.nunique())
# Out:
# Country                              6
# Year                                16
# Life expectancy at birth (years)    69
# GDP                                 96
# dtype: int64

# %% [markdown]
# There should be 16 rows for each country, otherwise there could be missing data that needs to be dealt with... There are 6 countries and 96 GDP. Simply performing a division allows me to see we have all 16 years per Country. But just to be sure:

# %%
print(pd.unique(df_new['Country']))
Country = pd.unique(df_new['Country'])
# Out:
# ['Chile' 'China' 'Germany' 'Mexico' 'United States of America' 'Zimbabwe']

# %%
df_CY= df_new[df_new.columns[0:2]]
for variable in Country:
    print(df_CY[df_CY.Country == variable].head(16))
# Out:
#    Country  Year
# 0    Chile  2000
# 1    Chile  2001
# 2    Chile  2002
# 3    Chile  2003
# 4    Chile  2004
# 5    Chile  2005
# 6    Chile  2006
# 7    Chile  2007
# 8    Chile  2008
# 9    Chile  2009
# 10   Chile  2010
# 11   Chile  2011
# 12   Chile  2012
# 13   Chile  2013
# 14   Chile  2014
# 15   Chile  2015
#    Country  Year
# 16   China  2000
# 17   China  2001
# 18   China  2002
# 19   China  2003
# 20   China  2004
# 21   China  2005
# 22   China  2006
# 23   China  2007
# 24   China  2008
# 25   China  2009
# 26   China  2010
# 27   China  2011
# 28   China  2012
# 29   China  2013
# 30   China  2014
# 31   China  2015
#     Country  Year
# 32  Germany  2000
# 33  Germany  2001
# 34  Germany  2002
# 35  Germany  2003
# 36  Germany  2004
# 37  Germany  2005
# 38  Germany  2006
# 39  Germany  2007
# 40  Germany  2008
# 41  Germany  2009
# 42  Germany  2010
# 43  Germany  2011
# 44  Germany  2012
# 45  Germany  2013
# 46  Germany  2014
# 47  Germany  2015
# ...

# %% [markdown]
# **Has life expectancy increased overtime in the 6 nations listed?**

# %%
Years= [2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015]
plt.figure(figsize=(8,6))
sns.lineplot(x= "Year", y= "Life expectancy at birth (years)", hue= "Country", palette= "bright", data= df_new, alpha=0.5)
plt.title("Does Life Expectancy Change Over Time?", weight= 'bold')
plt.legend(bbox_to_anchor=(1.02, 1), loc='upper left', borderaxespad=0)
plt.xticks(Years, rotation=45)
plt.show()
plt.clf()

# %% [markdown]
# **Has GDP increased overtime in the 6 nations listed?**

# %%
plt.figure(figsize=(8,6))
sns.lineplot(x= "Year", y= "GDP", hue= "Country", palette= "bright", data= df_new, alpha=0.5)
plt.title("Does GDP change Over Time?", weight= 'bold')
plt.legend(bbox_to_anchor=(1.02, 1), loc='upper left', borderaxespad=0)
plt.xticks(Years, rotation=45)
plt.show()
plt.clf()

# %% [markdown]
# **What has the average life expectancy been across the last 15 years for each nation?**

# %%
Average_Life_Expectancy_All= np.mean(df_new['Life expectancy at birth (years)'])
for nation in Country:
    print('The average life expectancy at birth in ' + nation + ' is ' + str(np.round(np.mean(df_new['Life expectancy at birth (years)'][df_new.Country== nation]))))
print('The total average across all countries for 15 years is ' + str(np.round(Average_Life_Expectancy_All)))
# Out:
# The average life expectancy at birth in Chile is 79.0
# The average life expectancy at birth in China is 74.0
# The average life expectancy at birth in Germany is 80.0
# The average life expectancy at birth in Mexico is 76.0
# The average life expectancy at birth in United States of America is 78.0
# The average life expectancy at birth in Zimbabwe is 50.0
# The total average across all countries for 15 years is 73.0

# %% [markdown]
# **What is the distribution of the life expectancies?**

# %%
plt.figure(figsize=(8,6))
plt.hist(df_new['Life expectancy at birth (years)'],bins=12, color= "Blue")
plt.title('Distribution of life expectancy 2000-2015', weight='bold')
plt.ylabel('Frequency')
plt.xlabel('Life Expectancy (years)')
plt.show()
plt.close()

# %% [markdown]
# **What is the distribution of the GDP?**

# %%
plt.figure(figsize=(8,6))
plt.hist(df_new['GDP'],bins=12, color= 'Purple')
plt.title('Distribution of GDP 2000-2015', weight= 'bold')
plt.ylabel('Frequency')
plt.xlabel('GDP')
plt.show()
plt.close()

# %% [markdown]
# **Is there a correlation between GDP and Life Expectancy?**

# %%
plt.figure(figsize=(8,6))
ax= plt.subplot()
sns.scatterplot(x= df_new['Life expectancy at birth (years)'], y= df_new.GDP, hue=df_new.Country, s=45)
plt.legend(bbox_to_anchor=(1.02, 1), loc='upper left', borderaxespad=0)
ax.set_title('Relationship between GDP and Life Expectancy 2000-2015', pad=20, weight= 'bold')
plt.show()

# %% [markdown]
# # Conclusions
